# %%
import json
from tqdm import tqdm
import itertools
import pdb
import glob
import os
from PIL import Image
from natsort import natsorted

# %% [markdown]
# # Utilities

# %%
def divid_train_val_image(image_dir, img_ext, val_ratio):
    files = glob.glob(os.path.join(image_dir, "*" + img_ext))
    
    files = natsorted(files)
    val_files = []
    train_files = []
    val_ratio_rpl = 1/val_ratio
    sum_ration = 0
    for idx, file in enumerate(files):
        sum_ration += val_ratio
        if sum_ration > 1:
            sum_ration = 0
            val_files.append(file)
        else:
            train_files.append(file)
            
    return train_files, val_files

# %%
image_dir = r"L:\Datasets\ocean_city\processed_json"
img_ext = ".json"
val_ratio = 0.2

train_files, val_files = divid_train_val_image(image_dir, img_ext, val_ratio)
print(len(train_files), len(val_files))
# Out:
# 138 27

# %%
files = glob.glob(os.path.join(image_dir, "*" + img_ext))

# %%
files = glob.glob(os.path.join(r"L:\Datasets\ocean_city\processed_json\*.json"))
files = natsorted(files)
files
# Out:
# ['L:\\Datasets\\ocean_city\\processed_json\\1.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\2.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\3.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\4.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\5.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\6.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\8.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\9.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\10.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\11.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\13.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\14.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\15.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\16.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\17.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\20.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\21.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\22.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\23.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\24.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\26.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\27.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\28.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\29.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\30.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\32.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\34.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\35.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\36.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\37.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\38.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\39.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\40.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\41.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\42.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\43.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\44.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\45.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\46.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\47.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\48.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\50.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\51.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\52.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\53.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\55.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\56.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\57.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\59.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\60.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\61.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\62.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\63.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\67.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\68.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\69.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\70.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\71.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\72.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\73.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\74.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\75.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\76.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\77.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\78.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\79.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\80.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\81.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\82.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\83.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\84.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\85.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\86.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\87.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\88.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\89.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\90.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\91.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\92.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\93.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\94.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\95.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\96.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\97.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\98.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\99.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\100.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\101.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\102.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\103.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\104.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\105.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\106.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\107.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\108.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\109.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\110.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\111.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\112.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\113.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\114.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\115.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\116.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\117.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\118.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\119.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\120.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\121.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\122.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\123.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\124.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\125.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\126.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\127.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\128.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\129.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\130.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\131.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\132.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\133.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\134.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\135.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\136.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\137.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\139.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\140.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\141.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\142.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\143.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\144.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\145.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\146.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\147.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\148.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\149.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\150.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\151.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\152.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\153.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\156.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\157.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\158.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\159.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\160.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\161.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\162.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\163.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\164.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\165.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\166.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\175.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\176.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\177.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\178.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\180.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\183.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\185.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\186.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\187.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\188.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\189.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\190.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\191.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\192.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\193.json']

# %% [markdown]
# # Create image json

# %%
def create_image_json(files):
#     with open('gqa_image_metadata.json', 'w') as outfile:  
#     json.dump(gqa_image_data, outfile)
    results = []
    for file in files:
        file = file.replace(".json", ".jpg")
        img = Image.open(file)
        
        img_name = os.path.basename(file).replace(".jpg", "")
        
        image_num = img_name.split("_")[0]
        image_num = int(image_num)
        
        img_h, img_w = img.size
        
        # print(img_w, img_h)
        data_dict = {"image_id": int(img_name),
                     "image_num": int(image_num),
                     "width": img_w,
                     "height": img_h,
                    "url": None, 
                    "flickr_id": None,
                    "coco_id": None,
                    "anti_prop": 0.0}
        results.append(data_dict)
        
    return results
        
#     print(results)

# %%
# for image_set in (train_files, val_files):
jdata = create_image_json(train_files)
with open(r'L:\Datasets\ocean_city\image_train.json', 'w') as outfile:  
    json.dump(jdata, outfile, indent=2)
    
jdata = create_image_json(val_files)
with open(r'L:\Datasets\ocean_city\image_val.json', 'w') as outfile:  
    json.dump(jdata, outfile, indent=2)

# %%
jdata = create_image_json(files)
with open(r'L:\Datasets\ocean_city\image.json', 'w') as outfile:  
    json.dump(jdata, outfile, indent=2)

# %% [markdown]
# # Create object json

# %%
def create_obj_dict(json_list, obj_list):
    
    for file in json_list:
        f = open(file, 'r')
        print(file)
        jdata = json.load(f)
                 
        shapes = jdata['shapes']
        image_id = os.path.basename(file).replace(".json", "")
        image_num = image_id.split("_")[0]
        image_url = ""
        objects = []
         
                 
        tmp_dict = {'image_id' : int(image_id), 
                    "image_num": int(image_num),
                    'objects' : [], 
                    'image_url' : image_url}
                                    
        for shape in shapes:
            points = shape['points']
            points = np.array(points)
                 
            x = int(min(points[:, 0]))
            y = int(min(points[:, 1]) )                 
            w = int(max(points[:, 0]) - min(points[:, 0]))
            h = int(max(points[:, 1]) - min(points[:, 1]) )
            name = shape["label"]
            object_id = shape["object_id"]
            
            object_dict = {'names': [shape['label']],  # a list! Different from official website!!
                           'object_id': object_id,
                           'merged_object_ids': [],
                           'synsets': [shape['label']],                         
                           'x': x,                           
                           'y': y,
                           'w': w,
                           'h': h}
            objects.append(object_dict)

            tmp_dict['objects'] = objects     
            
        obj_list.append(tmp_dict)
            
        
    return obj_list

# %%
obj_list = []

create_obj_dict(train_files, obj_list)

with open(r'L:\Datasets\ocean_city\objects_train.json', 'w') as outfile:  
    json.dump(obj_list, outfile, indent=2)

obj_list = []
create_obj_dict(val_files, obj_list)
with open(r'L:\Datasets\ocean_city\objects_val.json', 'w') as outfile:  
    json.dump(obj_list, outfile, indent=2)

# %%
obj_list = []
create_obj_dict(files, obj_list)
with open(r'L:\Datasets\ocean_city\objects.json', 'w') as outfile:  
    json.dump(obj_list, outfile, indent=2)
# Out:
# L:\Datasets\ocean_city\processed_json\1.json
# L:\Datasets\ocean_city\processed_json\2.json
# L:\Datasets\ocean_city\processed_json\3.json
# L:\Datasets\ocean_city\processed_json\4.json
# L:\Datasets\ocean_city\processed_json\5.json
# L:\Datasets\ocean_city\processed_json\6.json
# L:\Datasets\ocean_city\processed_json\8.json
# L:\Datasets\ocean_city\processed_json\9.json
# L:\Datasets\ocean_city\processed_json\10.json
# L:\Datasets\ocean_city\processed_json\11.json
# L:\Datasets\ocean_city\processed_json\13.json
# L:\Datasets\ocean_city\processed_json\14.json
# L:\Datasets\ocean_city\processed_json\15.json
# L:\Datasets\ocean_city\processed_json\16.json
# L:\Datasets\ocean_city\processed_json\17.json
# L:\Datasets\ocean_city\processed_json\20.json
# L:\Datasets\ocean_city\processed_json\21.json
# L:\Datasets\ocean_city\processed_json\22.json
# L:\Datasets\ocean_city\processed_json\23.json
# L:\Datasets\ocean_city\processed_json\24.json
# L:\Datasets\ocean_city\processed_json\26.json
# L:\Datasets\ocean_city\processed_json\27.json
# L:\Datasets\ocean_city\processed_json\28.json
# L:\Datasets\ocean_city\processed_json\29.json
# L:\Datasets\ocean_city\processed_json\30.json
# L:\Datasets\ocean_city\processed_json\32.json
# L:\Datasets\ocean_city\processed_json\34.json
# L:\Datasets\ocean_city\processed_json\35.json
# L:\Datasets\ocean_city\processed_json\36.json
# L:\Datasets\ocean_city\processed_json\37.json
# L:\Datasets\ocean_city\processed_json\38.json
# L:\Datasets\ocean_city\processed_json\39.json
# L:\Datasets\ocean_city\processed_json\40.json
# L:\Datasets\ocean_city\processed_json\41.json
# L:\Datasets\ocean_city\processed_json\42.json
# L:\Datasets\ocean_city\processed_json\43.json
# L:\Datasets\ocean_city\processed_json\44.json
# L:\Datasets\ocean_city\processed_json\45.json
# L:\Datasets\ocean_city\processed_json\46.json
# L:\Datasets\ocean_city\processed_json\47.json
# L:\Datasets\ocean_city\processed_json\48.json
# L:\Datasets\ocean_city\processed_json\50.json
# L:\Datasets\ocean_city\processed_json\51.json
# L:\Datasets\ocean_city\processed_json\52.json
# L:\Datasets\ocean_city\processed_json\53.json
# L:\Datasets\ocean_city\processed_json\55.json
# L:\Datasets\ocean_city\processed_json\56.json
# L:\Datasets\ocean_city\processed_json\57.json
# L:\Datasets\ocean_city\processed_json\59.json
# L:\Datasets\ocean_city\processed_json\60.json
# L:\Datasets\ocean_city\processed_json\61.json
# L:\Datasets\ocean_city\processed_json\62.json
# L:\Datasets\ocean_city\processed_json\63.json
# L:\Datasets\ocean_city\processed_json\67.json
# L:\Datasets\ocean_city\processed_json\68.json
# L:\Datasets\ocean_city\processed_json\69.json
# L:\Datasets\ocean_city\processed_json\70.json
# L:\Datasets\ocean_city\processed_json\71.json
# L:\Datasets\ocean_city\processed_json\72.json
# L:\Datasets\ocean_city\processed_json\73.json
# L:\Datasets\ocean_city\processed_json\74.json
# L:\Datasets\ocean_city\processed_json\75.json
# L:\Datasets\ocean_city\processed_json\76.json
# L:\Datasets\ocean_city\processed_json\77.json
# L:\Datasets\ocean_city\processed_json\78.json
# L:\Datasets\ocean_city\processed_json\79.json
# L:\Datasets\ocean_city\processed_json\80.json
# L:\Datasets\ocean_city\processed_json\81.json
# L:\Datasets\ocean_city\processed_json\82.json
# L:\Datasets\ocean_city\processed_json\83.json
# L:\Datasets\ocean_city\processed_json\84.json
# L:\Datasets\ocean_city\processed_json\85.json
# L:\Datasets\ocean_city\processed_json\86.json
# L:\Datasets\ocean_city\processed_json\87.json
# L:\Datasets\ocean_city\processed_json\88.json
# L:\Datasets\ocean_city\processed_json\89.json
# L:\Datasets\ocean_city\processed_json\90.json
# L:\Datasets\ocean_city\processed_json\91.json
# L:\Datasets\ocean_city\processed_json\92.json
# L:\Datasets\ocean_city\processed_json\93.json
# L:\Datasets\ocean_city\processed_json\94.json
# L:\Datasets\ocean_city\processed_json\95.json
# L:\Datasets\ocean_city\processed_json\96.json
# L:\Datasets\ocean_city\processed_json\97.json
# L:\Datasets\ocean_city\processed_json\98.json
# L:\Datasets\ocean_city\processed_json\99.json
# L:\Datasets\ocean_city\processed_json\100.json
# L:\Datasets\ocean_city\processed_json\101.json
# L:\Datasets\ocean_city\processed_json\102.json
# L:\Datasets\ocean_city\processed_json\103.json
# L:\Datasets\ocean_city\processed_json\104.json
# L:\Datasets\ocean_city\processed_json\105.json
# L:\Datasets\ocean_city\processed_json\106.json
# L:\Datasets\ocean_city\processed_json\107.json
# L:\Datasets\ocean_city\processed_json\108.json
# L:\Datasets\ocean_city\processed_json\109.json
# L:\Datasets\ocean_city\processed_json\110.json
# L:\Datasets\ocean_city\processed_json\111.json
# L:\Datasets\ocean_city\processed_json\112.json
# L:\Datasets\ocean_city\processed_json\113.json
# L:\Datasets\ocean_city\processed_json\114.json
# L:\Datasets\ocean_city\processed_json\115.json
# L:\Datasets\ocean_city\processed_json\116.json
# L:\Datasets\ocean_city\processed_json\117.json
# L:\Datasets\ocean_city\processed_json\118.json
# L:\Datasets\ocean_city\processed_json\119.json
# L:\Datasets\ocean_city\processed_json\120.json
# L:\Datasets\ocean_city\processed_json\121.json
# L:\Datasets\ocean_city\processed_json\122.json
# L:\Datasets\ocean_city\processed_json\123.json
# L:\Datasets\ocean_city\processed_json\124.json
# L:\Datasets\ocean_city\processed_json\125.json
# L:\Datasets\ocean_city\processed_json\126.json
# L:\Datasets\ocean_city\processed_json\127.json
# L:\Datasets\ocean_city\processed_json\128.json
# L:\Datasets\ocean_city\processed_json\129.json
# L:\Datasets\ocean_city\processed_json\130.json
# L:\Datasets\ocean_city\processed_json\131.json
# L:\Datasets\ocean_city\processed_json\132.json
# L:\Datasets\ocean_city\processed_json\133.json
# L:\Datasets\ocean_city\processed_json\134.json
# L:\Datasets\ocean_city\processed_json\135.json
# L:\Datasets\ocean_city\processed_json\136.json
# L:\Datasets\ocean_city\processed_json\137.json
# L:\Datasets\ocean_city\processed_json\139.json
# L:\Datasets\ocean_city\processed_json\140.json
# L:\Datasets\ocean_city\processed_json\141.json
# L:\Datasets\ocean_city\processed_json\142.json
# L:\Datasets\ocean_city\processed_json\143.json
# L:\Datasets\ocean_city\processed_json\144.json
# L:\Datasets\ocean_city\processed_json\145.json
# L:\Datasets\ocean_city\processed_json\146.json
# L:\Datasets\ocean_city\processed_json\147.json
# L:\Datasets\ocean_city\processed_json\148.json
# L:\Datasets\ocean_city\processed_json\149.json
# L:\Datasets\ocean_city\processed_json\150.json
# L:\Datasets\ocean_city\processed_json\151.json
# L:\Datasets\ocean_city\processed_json\152.json
# L:\Datasets\ocean_city\processed_json\153.json
# L:\Datasets\ocean_city\processed_json\156.json
# L:\Datasets\ocean_city\processed_json\157.json
# L:\Datasets\ocean_city\processed_json\158.json
# L:\Datasets\ocean_city\processed_json\159.json
# L:\Datasets\ocean_city\processed_json\160.json
# L:\Datasets\ocean_city\processed_json\161.json
# L:\Datasets\ocean_city\processed_json\162.json
# L:\Datasets\ocean_city\processed_json\163.json
# L:\Datasets\ocean_city\processed_json\164.json
# L:\Datasets\ocean_city\processed_json\165.json
# L:\Datasets\ocean_city\processed_json\166.json
# L:\Datasets\ocean_city\processed_json\175.json
# L:\Datasets\ocean_city\processed_json\176.json
# L:\Datasets\ocean_city\processed_json\177.json
# L:\Datasets\ocean_city\processed_json\178.json
# L:\Datasets\ocean_city\processed_json\180.json
# L:\Datasets\ocean_city\processed_json\183.json
# L:\Datasets\ocean_city\processed_json\185.json
# L:\Datasets\ocean_city\processed_json\186.json
# L:\Datasets\ocean_city\processed_json\187.json
# L:\Datasets\ocean_city\processed_json\188.json
# L:\Datasets\ocean_city\processed_json\189.json
# L:\Datasets\ocean_city\processed_json\190.json
# L:\Datasets\ocean_city\processed_json\191.json
# L:\Datasets\ocean_city\processed_json\192.json
# L:\Datasets\ocean_city\processed_json\193.json

# %% [markdown]
# # create relationships

# %%
def create_rel_dict(json_list, rel_list):
    
    for file in json_list:
        f = open(file, 'r')
        print("Processing: ", file)
        jdata = json.load(f)
                 
        shapes = jdata['shapes']
        image_id = os.path.basename(file).replace(".json", "")
        image_num = image_id.split("_")[0]
        image_url = ""
        objects = []
        
        obj_list = []
         
        object_ids = []
        
        tmp_dict = {'image_id' : int(image_id), 
                    "image_num": int(image_num),
                    'objects' : [], 
                    'image_url' : image_url}
            
        tmp_dict = {'objects' : []}
                
        for shape in shapes:
            points = shape['points']
            points = np.array(points)
                 
            x = int(min(points[:, 0]))
            y = int(min(points[:, 1]) )                 
            w = int(max(points[:, 0]) - min(points[:, 0]))
            h = int(max(points[:, 1]) - min(points[:, 1]) )
            name = shape["label"]
            object_id = shape["object_id"]
            
            object_ids.append(object_id)
            
            object_dict = {'names': shape['label'],  # a list! Different from official website!!
                           'object_id': object_id,
                           'synsets': [shape['label']],                         
                           'x': x,                           
                           'y': y,
                           'w': w,
                           'h': h}
   
            
            obj_list.append(object_dict)
            
        relationships = jdata["relationships"]
        
#         print(object_ids)
        
        rel_dict = {}
        rel_dict['image_id'] = int(image_id)
        rel_dict['relationships'] = []
        
        for rel in relationships:
            
            single_relation_dict = {}
            
            
#             subject_name = rel["subject"]["name"] 
            subject_id   = rel["subject"]["object_id"]
            subject_id = int(subject_id)
#             print("subject_id:", subject_id)
#             oject_name   = rel["object"]["name"] 
            object_id    = rel["object"]["object_id"]
            object_id = int(object_id)
            predicate    = rel["predicate"]
            
            subject_idx = object_ids.index(subject_id)
            object_idx = object_ids.index(object_id)
            
            subject_dict = obj_list[subject_idx]
            object_dict = obj_list[object_idx]
            
            single_relation_dict["relationship_id"] = rel["relationship_id"]
            single_relation_dict["predicate"] = rel["predicate"]            
            single_relation_dict["synsets"] = []
            single_relation_dict["subject"] = subject_dict
            single_relation_dict["object"]  = object_dict
            
            rel_dict['relationships'].append(single_relation_dict)
        
        rel_list.append(rel_dict)
            
        
    return rel_list

# %%
rel_list = []

create_rel_dict(train_files, rel_list)

with open(r'L:\Datasets\ocean_city\relationships_train.json', 'w') as outfile:  
    json.dump(rel_list, outfile, indent=2)

rel_list = []
create_rel_dict(val_files, rel_list)
with open(r'L:\Datasets\ocean_city\relationships_val.json', 'w') as outfile:  
    json.dump(rel_list, outfile, indent=2)

# %%
rel_list = []
create_rel_dict(files, rel_list)
with open(r'L:\Datasets\ocean_city\relationships.json', 'w') as outfile:  
    json.dump(rel_list, outfile, indent=2)
# Out:
# Processing:  L:\Datasets\ocean_city\processed_json\1.json
# Processing:  L:\Datasets\ocean_city\processed_json\2.json
# Processing:  L:\Datasets\ocean_city\processed_json\3.json
# Processing:  L:\Datasets\ocean_city\processed_json\4.json
# Processing:  L:\Datasets\ocean_city\processed_json\5.json
# Processing:  L:\Datasets\ocean_city\processed_json\6.json
# Processing:  L:\Datasets\ocean_city\processed_json\8.json
# Processing:  L:\Datasets\ocean_city\processed_json\9.json
# Processing:  L:\Datasets\ocean_city\processed_json\10.json
# Processing:  L:\Datasets\ocean_city\processed_json\11.json
# Processing:  L:\Datasets\ocean_city\processed_json\13.json
# Processing:  L:\Datasets\ocean_city\processed_json\14.json
# Processing:  L:\Datasets\ocean_city\processed_json\15.json
# Processing:  L:\Datasets\ocean_city\processed_json\16.json
# Processing:  L:\Datasets\ocean_city\processed_json\17.json
# Processing:  L:\Datasets\ocean_city\processed_json\20.json
# Processing:  L:\Datasets\ocean_city\processed_json\21.json
# Processing:  L:\Datasets\ocean_city\processed_json\22.json
# Processing:  L:\Datasets\ocean_city\processed_json\23.json
# Processing:  L:\Datasets\ocean_city\processed_json\24.json
# Processing:  L:\Datasets\ocean_city\processed_json\26.json
# Processing:  L:\Datasets\ocean_city\processed_json\27.json
# Processing:  L:\Datasets\ocean_city\processed_json\28.json
# Processing:  L:\Datasets\ocean_city\processed_json\29.json
# Processing:  L:\Datasets\ocean_city\processed_json\30.json
# Processing:  L:\Datasets\ocean_city\processed_json\32.json
# Processing:  L:\Datasets\ocean_city\processed_json\34.json
# Processing:  L:\Datasets\ocean_city\processed_json\35.json
# Processing:  L:\Datasets\ocean_city\processed_json\36.json
# Processing:  L:\Datasets\ocean_city\processed_json\37.json
# Processing:  L:\Datasets\ocean_city\processed_json\38.json
# Processing:  L:\Datasets\ocean_city\processed_json\39.json
# Processing:  L:\Datasets\ocean_city\processed_json\40.json
# Processing:  L:\Datasets\ocean_city\processed_json\41.json
# Processing:  L:\Datasets\ocean_city\processed_json\42.json
# Processing:  L:\Datasets\ocean_city\processed_json\43.json
# Processing:  L:\Datasets\ocean_city\processed_json\44.json
# Processing:  L:\Datasets\ocean_city\processed_json\45.json
# Processing:  L:\Datasets\ocean_city\processed_json\46.json
# Processing:  L:\Datasets\ocean_city\processed_json\47.json
# Processing:  L:\Datasets\ocean_city\processed_json\48.json
# Processing:  L:\Datasets\ocean_city\processed_json\50.json
# Processing:  L:\Datasets\ocean_city\processed_json\51.json
# Processing:  L:\Datasets\ocean_city\processed_json\52.json
# Processing:  L:\Datasets\ocean_city\processed_json\53.json
# Processing:  L:\Datasets\ocean_city\processed_json\55.json
# Processing:  L:\Datasets\ocean_city\processed_json\56.json
# Processing:  L:\Datasets\ocean_city\processed_json\57.json
# Processing:  L:\Datasets\ocean_city\processed_json\59.json
# Processing:  L:\Datasets\ocean_city\processed_json\60.json
# Processing:  L:\Datasets\ocean_city\processed_json\61.json
# Processing:  L:\Datasets\ocean_city\processed_json\62.json
# Processing:  L:\Datasets\ocean_city\processed_json\63.json
# Processing:  L:\Datasets\ocean_city\processed_json\67.json
# Processing:  L:\Datasets\ocean_city\processed_json\68.json
# Processing:  L:\Datasets\ocean_city\processed_json\69.json
# Processing:  L:\Datasets\ocean_city\processed_json\70.json
# Processing:  L:\Datasets\ocean_city\processed_json\71.json
# Processing:  L:\Datasets\ocean_city\processed_json\72.json
# Processing:  L:\Datasets\ocean_city\processed_json\73.json
# Processing:  L:\Datasets\ocean_city\processed_json\74.json
# Processing:  L:\Datasets\ocean_city\processed_json\75.json
# Processing:  L:\Datasets\ocean_city\processed_json\76.json
# Processing:  L:\Datasets\ocean_city\processed_json\77.json
# Processing:  L:\Datasets\ocean_city\processed_json\78.json
# Processing:  L:\Datasets\ocean_city\processed_json\79.json
# Processing:  L:\Datasets\ocean_city\processed_json\80.json
# Processing:  L:\Datasets\ocean_city\processed_json\81.json
# Processing:  L:\Datasets\ocean_city\processed_json\82.json
# Processing:  L:\Datasets\ocean_city\processed_json\83.json
# Processing:  L:\Datasets\ocean_city\processed_json\84.json
# Processing:  L:\Datasets\ocean_city\processed_json\85.json
# Processing:  L:\Datasets\ocean_city\processed_json\86.json
# Processing:  L:\Datasets\ocean_city\processed_json\87.json
# Processing:  L:\Datasets\ocean_city\processed_json\88.json
# Processing:  L:\Datasets\ocean_city\processed_json\89.json
# Processing:  L:\Datasets\ocean_city\processed_json\90.json
# Processing:  L:\Datasets\ocean_city\processed_json\91.json
# Processing:  L:\Datasets\ocean_city\processed_json\92.json
# Processing:  L:\Datasets\ocean_city\processed_json\93.json
# Processing:  L:\Datasets\ocean_city\processed_json\94.json
# Processing:  L:\Datasets\ocean_city\processed_json\95.json
# Processing:  L:\Datasets\ocean_city\processed_json\96.json
# Processing:  L:\Datasets\ocean_city\processed_json\97.json
# Processing:  L:\Datasets\ocean_city\processed_json\98.json
# Processing:  L:\Datasets\ocean_city\processed_json\99.json
# Processing:  L:\Datasets\ocean_city\processed_json\100.json
# Processing:  L:\Datasets\ocean_city\processed_json\101.json
# Processing:  L:\Datasets\ocean_city\processed_json\102.json
# Processing:  L:\Datasets\ocean_city\processed_json\103.json
# Processing:  L:\Datasets\ocean_city\processed_json\104.json
# Processing:  L:\Datasets\ocean_city\processed_json\105.json
# Processing:  L:\Datasets\ocean_city\processed_json\106.json
# Processing:  L:\Datasets\ocean_city\processed_json\107.json
# Processing:  L:\Datasets\ocean_city\processed_json\108.json
# Processing:  L:\Datasets\ocean_city\processed_json\109.json
# Processing:  L:\Datasets\ocean_city\processed_json\110.json
# Processing:  L:\Datasets\ocean_city\processed_json\111.json
# Processing:  L:\Datasets\ocean_city\processed_json\112.json
# Processing:  L:\Datasets\ocean_city\processed_json\113.json
# Processing:  L:\Datasets\ocean_city\processed_json\114.json
# Processing:  L:\Datasets\ocean_city\processed_json\115.json
# Processing:  L:\Datasets\ocean_city\processed_json\116.json
# Processing:  L:\Datasets\ocean_city\processed_json\117.json
# Processing:  L:\Datasets\ocean_city\processed_json\118.json
# Processing:  L:\Datasets\ocean_city\processed_json\119.json
# Processing:  L:\Datasets\ocean_city\processed_json\120.json
# Processing:  L:\Datasets\ocean_city\processed_json\121.json
# Processing:  L:\Datasets\ocean_city\processed_json\122.json
# Processing:  L:\Datasets\ocean_city\processed_json\123.json
# Processing:  L:\Datasets\ocean_city\processed_json\124.json
# Processing:  L:\Datasets\ocean_city\processed_json\125.json
# Processing:  L:\Datasets\ocean_city\processed_json\126.json
# Processing:  L:\Datasets\ocean_city\processed_json\127.json
# Processing:  L:\Datasets\ocean_city\processed_json\128.json
# Processing:  L:\Datasets\ocean_city\processed_json\129.json
# Processing:  L:\Datasets\ocean_city\processed_json\130.json
# Processing:  L:\Datasets\ocean_city\processed_json\131.json
# Processing:  L:\Datasets\ocean_city\processed_json\132.json
# Processing:  L:\Datasets\ocean_city\processed_json\133.json
# Processing:  L:\Datasets\ocean_city\processed_json\134.json
# Processing:  L:\Datasets\ocean_city\processed_json\135.json
# Processing:  L:\Datasets\ocean_city\processed_json\136.json
# Processing:  L:\Datasets\ocean_city\processed_json\137.json
# Processing:  L:\Datasets\ocean_city\processed_json\139.json
# Processing:  L:\Datasets\ocean_city\processed_json\140.json
# Processing:  L:\Datasets\ocean_city\processed_json\141.json
# Processing:  L:\Datasets\ocean_city\processed_json\142.json
# Processing:  L:\Datasets\ocean_city\processed_json\143.json
# Processing:  L:\Datasets\ocean_city\processed_json\144.json
# Processing:  L:\Datasets\ocean_city\processed_json\145.json
# Processing:  L:\Datasets\ocean_city\processed_json\146.json
# Processing:  L:\Datasets\ocean_city\processed_json\147.json
# Processing:  L:\Datasets\ocean_city\processed_json\148.json
# Processing:  L:\Datasets\ocean_city\processed_json\149.json
# Processing:  L:\Datasets\ocean_city\processed_json\150.json
# Processing:  L:\Datasets\ocean_city\processed_json\151.json
# Processing:  L:\Datasets\ocean_city\processed_json\152.json
# Processing:  L:\Datasets\ocean_city\processed_json\153.json
# Processing:  L:\Datasets\ocean_city\processed_json\156.json
# Processing:  L:\Datasets\ocean_city\processed_json\157.json
# Processing:  L:\Datasets\ocean_city\processed_json\158.json
# Processing:  L:\Datasets\ocean_city\processed_json\159.json
# Processing:  L:\Datasets\ocean_city\processed_json\160.json
# Processing:  L:\Datasets\ocean_city\processed_json\161.json
# Processing:  L:\Datasets\ocean_city\processed_json\162.json
# Processing:  L:\Datasets\ocean_city\processed_json\163.json
# Processing:  L:\Datasets\ocean_city\processed_json\164.json
# Processing:  L:\Datasets\ocean_city\processed_json\165.json
# Processing:  L:\Datasets\ocean_city\processed_json\166.json
# Processing:  L:\Datasets\ocean_city\processed_json\175.json
# Processing:  L:\Datasets\ocean_city\processed_json\176.json
# Processing:  L:\Datasets\ocean_city\processed_json\177.json
# Processing:  L:\Datasets\ocean_city\processed_json\178.json
# Processing:  L:\Datasets\ocean_city\processed_json\180.json
# Processing:  L:\Datasets\ocean_city\processed_json\183.json
# Processing:  L:\Datasets\ocean_city\processed_json\185.json
# Processing:  L:\Datasets\ocean_city\processed_json\186.json
# Processing:  L:\Datasets\ocean_city\processed_json\187.json
# Processing:  L:\Datasets\ocean_city\processed_json\188.json
# Processing:  L:\Datasets\ocean_city\processed_json\189.json
# Processing:  L:\Datasets\ocean_city\processed_json\190.json
# Processing:  L:\Datasets\ocean_city\processed_json\191.json
# Processing:  L:\Datasets\ocean_city\processed_json\192.json
# Processing:  L:\Datasets\ocean_city\processed_json\193.json

# %% [markdown]
# # create object/relation list

# %%
def list_to_file(a_list, file_name):
    with open(file_name, mode='wt', encoding='utf-8') as myfile:
        myfile.write('\n'.join(a_list))
        myfile.write('\n')

# %%
json_file = r'L:\Datasets\ocean_city\objects.json'

# %%
f = open(json_file, 'r')
jdata = json.load(f)

# %%
object_list = []
object_set = set([])
for img_dict in jdata:
    objects = img_dict['objects']
    for obj in objects:
        object_list.append(obj["names"])
        object_set.add(obj["names"])
#         print(len(object_list), len(object_set))

# %%
file_name = r'L:\Datasets\ocean_city\objects_list.txt'
list_to_file(list(object_set), file_name)

# %% [markdown]
# For relationships

# %%
json_file = r'L:\Datasets\ocean_city\relationships.json'
f = open(json_file, 'r')
jdata = json.load(f)
relationship_list = []
relationship_set = set([])
for rel_dict in jdata:
    relationships = rel_dict['relationships']
    for rel in relationships:
        relationship_list.append(rel["predicate"])
        relationship_set.add(rel["predicate"])
#         print(len(object_list), len(object_set))

# %%
file_name = r'L:\Datasets\ocean_city\relationships_list.txt'
list_to_file(list(relationship_set), file_name)

# %%
relationship_set
# Out:
# {'adjoin_to',
#  'along_with',
#  'component_of',
#  'connect_to',
#  'in_front_of',
#  'in_left_of'}

# %% [markdown]
# # look up json

# %%
json_file = r'L:\Datasets\Visual_Genome\objects.json'

f = open(json_file, 'r')

jdata = json.load(f)

# %%
len(jdata)
# Out:
# 108077

# %%
jdata[0]
# Out:
# {'image_id': 1,
#  'objects': [{'synsets': ['tree.n.01'],
#    'h': 557,
#    'object_id': 1058549,
#    'merged_object_ids': [],
#    'names': ['trees'],
#    'w': 799,
#    'y': 0,
#    'x': 0},
#   {'synsets': ['sidewalk.n.01'],
#    'h': 290,
#    'object_id': 1058534,
#    'merged_object_ids': [5046],
#    'names': ['sidewalk'],
#    'w': 722,
#    'y': 308,
#    'x': 78},
#   {'synsets': ['building.n.01'],
#    'h': 538,
#    'object_id': 1058508,
#    'merged_object_ids': [],
#    'names': ['building'],
#    'w': 222,
#    'y': 0,
#    'x': 1},
#   {'synsets': ['street.n.01'],
#    'h': 258,
#    'object_id': 1058539,
#    'merged_object_ids': [3798578],
#    'names': ['street'],
#    'w': 359,
#    'y': 283,
#    'x': 439},
#   {'synsets': ['wall.n.01'],
#    'h': 535,
#    'object_id': 1058543,
#    'merged_object_ids': [],
#    'names': ['wall'],
#    'w': 135,
#    'y': 1,
#    'x': 0},
#   {'synsets': ['tree.n.01'],
#    'h': 360,
#    'object_id': 1058545,
#    'merged_object_ids': [],
#    'names': ['tree'],
#    'w': 476,
#    'y': 0,
#    'x': 178},
#   {'synsets': ['shade.n.01'],
#    'h': 189,
#    'object_id': 5045,
#    'merged_object_ids': [],
#    'names': ['shade'],
#    'w': 274,
#    'y': 344,
#    'x': 116},
#   {'synsets': ['van.n.05'],
#    'h': 176,
#    'object_id': 1058542,
#    'merged_object_ids': [1058536],
#    'names': ['van'],
#    'w': 241,
#    'y': 278,
#    'x': 533},
#   {'synsets': ['trunk.n.01'],
#    'h': 348,
#    'object_id': 5055,
#    'merged_object_ids': [],
#    'names': ['tree trunk'],
#    'w': 78,
#    'y': 213,
#    'x': 623},
#   {'synsets': ['clock.n.01'],
#    'h': 363,
#    'object_id': 1058498,
#    'merged_object_ids': [],
#    'names': ['clock'],
#    'w': 77,
#    'y': 63,
#    'x': 422},
#   {'synsets': ['window.n.01'],
#    'h': 147,
#    'object_id': 3798579,
#    'merged_object_ids': [],
#    'names': ['windows'],
#    'w': 198,
#    'y': 1,
#    'x': 602},
#   {'synsets': ['man.n.01'],
#    'h': 248,
#    'object_id': 3798576,
#    'merged_object_ids': [1058540],
#    'names': ['man'],
#    'w': 82,
#    'y': 264,
#    'x': 367},
#   {'synsets': ['man.n.01'],
#    'h': 259,
#    'object_id': 3798577,
#    'merged_object_ids': [],
#    'names': ['man'],
#    'w': 57,
#    'y': 254,
#    'x': 238},
#   {'synsets': [],
#    'h': 430,
#    'object_id': 1058548,
#    'merged_object_ids': [],
#    'names': ['lamp post'],
#    'w': 43,
#    'y': 63,
#    'x': 537},
#   {'synsets': ['sign.n.02'],
#    'h': 179,
#    'object_id': 1058507,
#    'merged_object_ids': [],
#    'names': ['sign'],
#    'w': 78,
#    'y': 13,
#    'x': 123},
#   {'synsets': ['car.n.01'],
#    'h': 164,
#    'object_id': 1058515,
#    'merged_object_ids': [],
#    'names': ['car'],
#    'w': 80,
#    'y': 342,
#    'x': 719},
#   {'synsets': ['back.n.01'],
#    'h': 164,
#    'object_id': 5060,
#    'merged_object_ids': [],
#    'names': ['back'],
#    'w': 70,
#    'y': 345,
#    'x': 716},
#   {'synsets': ['jacket.n.01'],
#    'h': 98,
#    'object_id': 1058530,
#    'merged_object_ids': [],
#    'names': ['jacket'],
#    'w': 82,
#    'y': 296,
#    'x': 367},
#   {'synsets': ['car.n.01'],
#    'h': 95,
#    'object_id': 5049,
#    'merged_object_ids': [],
#    'names': ['car'],
#    'w': 78,
#    'y': 319,
#    'x': 478},
#   {'synsets': ['trouser.n.01'],
#    'h': 128,
#    'object_id': 1058531,
#    'merged_object_ids': [],
#    'names': ['pants'],
#    'w': 48,
#    'y': 369,
#    'x': 388},
#   {'synsets': ['shirt.n.01'],
#    'h': 103,
#    'object_id': 1058511,
#    'merged_object_ids': [],
#    'names': ['shirt'],
#    'w': 54,
#    'y': 287,
#    'x': 241},
#   {'synsets': ['parking_meter.n.01'],
#    'h': 143,
#    'object_id': 1058519,
#    'merged_object_ids': [],
#    'names': ['parking meter'],
#    'w': 26,
#    'y': 325,
#    'x': 577},
#   {'synsets': ['trouser.n.01'],
#    'h': 118,
#    'object_id': 1058528,
#    'merged_object_ids': [],
#    'names': ['pants'],
#    'w': 44,
#    'y': 384,
#    'x': 245},
#   {'synsets': ['shirt.n.01'],
#    'h': 102,
#    'object_id': 1058547,
#    'merged_object_ids': [],
#    'names': ['shirt'],
#    'w': 82,
#    'y': 295,
#    'x': 368},
#   {'synsets': ['shoe.n.01'],
#    'h': 28,
#    'object_id': 1058525,
#    'merged_object_ids': [5048],
#    'names': ['shoes'],
#    'w': 48,
#    'y': 485,
#    'x': 388},
#   {'synsets': ['arm.n.01'],
#    'h': 41,
#    'object_id': 1058546,
#    'merged_object_ids': [],
#    'names': ['arm'],
#    'w': 30,
#    'y': 285,
#    'x': 370},
#   {'synsets': ['bicycle.n.01'],
#    'h': 36,
#    'object_id': 1058535,
#    'merged_object_ids': [],
#    'names': ['bike'],
#    'w': 27,
#    'y': 319,
#    'x': 337},
#   {'synsets': ['bicycle.n.01'],
#    'h': 41,
#    'object_id': 5051,
#    'merged_object_ids': [],
#    'names': ['bike'],
#    'w': 27,
#    'y': 311,
#    'x': 321},
#   {'synsets': ['headlight.n.01'],
#    'h': 9,
#    'object_id': 5050,
#    'merged_object_ids': [],
#    'names': ['headlight'],
#    'w': 18,
#    'y': 370,
#    'x': 517},
#   {'synsets': ['spectacles.n.01'],
#    'h': 23,
#    'object_id': 1058518,
#    'merged_object_ids': [],
#    'names': ['glasses'],
#    'w': 43,
#    'y': 317,
#    'x': 448},
#   {'synsets': ['chin.n.01'],
#    'h': 8,
#    'object_id': 1058541,
#    'merged_object_ids': [],
#    'names': ['chin'],
#    'w': 9,
#    'y': 288,
#    'x': 401}],
#  'image_url': 'https://cs.stanford.edu/people/rak248/VG_100K_2/1.jpg'}

# %% [markdown]
# # Rename

# %%
file_dir = r"L:\Datasets\ocean_city\processed_json"
file_ext = ".json"
 
files = glob.glob(os.path.join(file_dir, "*" + file_ext))

len(files)
# Out:
# 165

# %%
files[0]
# Out:
# 'L:\\Datasets\\ocean_city\\processed_json\\1.json'

# %%
files
# Out:
# ['L:\\Datasets\\ocean_city\\processed_json\\1.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\10.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\100.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\101.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\102.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\103.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\104.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\105.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\106.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\107.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\108.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\109.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\11.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\110.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\111.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\112.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\113.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\114.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\115.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\116.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\117.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\118.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\119.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\120.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\121.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\122.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\123.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\124.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\125.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\126.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\127.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\128.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\129.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\13.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\130.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\131.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\132.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\133.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\134.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\135.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\136.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\137.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\139.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\14.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\140.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\141.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\142.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\143.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\144.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\145.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\146.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\147.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\148.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\149.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\15.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\150.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\151.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\152.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\153.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\156.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\157.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\158.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\159.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\16.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\160.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\161.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\162.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\163.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\164.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\165.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\166.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\17.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\175.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\176.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\177.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\178.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\180.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\183.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\185.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\186.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\187.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\188.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\189.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\190.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\191.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\192.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\193.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\2.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\20.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\21.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\22.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\23.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\24.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\26.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\27.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\28.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\29.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\3.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\30.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\32.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\34.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\35.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\36.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\37.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\38.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\39.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\4.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\40.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\41.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\42.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\43.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\44.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\45.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\46.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\47.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\48.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\5.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\50.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\51.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\52.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\53.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\55.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\56.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\57.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\59.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\6.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\60.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\61.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\62.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\63.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\67.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\68.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\69.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\70.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\71.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\72.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\73.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\74.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\75.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\76.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\77.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\78.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\79.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\8.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\80.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\81.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\82.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\83.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\84.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\85.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\86.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\87.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\88.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\89.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\9.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\90.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\91.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\92.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\93.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\94.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\95.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\96.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\97.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\98.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\99.json']

# %% [markdown]
# ## Rename image file

# %%
for idx, file in enumerate(files):
    file2 = file
    file = file.replace(".json.json", ".json")
    
    basename = os.path.basename(file)
#     print(basename)
    dir_name = os.path.dirname(file)
    ext = os.path.splitext(file)[1]
    new_name = basename.split("_")[0] #+ ext
#     new_name = basename 

    new_name = os.path.join(dir_name, new_name)
    print(new_name)
    
    os.rename(file2, new_name)
    
#     f = open(file, 'r')
#     jdata = json.load(f)
# Out:
# L:\Datasets\ocean_city\processed_json\1.json
# L:\Datasets\ocean_city\processed_json\10.json
# L:\Datasets\ocean_city\processed_json\100.json
# L:\Datasets\ocean_city\processed_json\101.json
# L:\Datasets\ocean_city\processed_json\102.json
# L:\Datasets\ocean_city\processed_json\103.json
# L:\Datasets\ocean_city\processed_json\104.json
# L:\Datasets\ocean_city\processed_json\105.json
# L:\Datasets\ocean_city\processed_json\106.json
# L:\Datasets\ocean_city\processed_json\107.json
# L:\Datasets\ocean_city\processed_json\108.json
# L:\Datasets\ocean_city\processed_json\109.json
# L:\Datasets\ocean_city\processed_json\11.json
# L:\Datasets\ocean_city\processed_json\110.json
# L:\Datasets\ocean_city\processed_json\111.json
# L:\Datasets\ocean_city\processed_json\112.json
# L:\Datasets\ocean_city\processed_json\113.json
# L:\Datasets\ocean_city\processed_json\114.json
# L:\Datasets\ocean_city\processed_json\115.json
# L:\Datasets\ocean_city\processed_json\116.json
# L:\Datasets\ocean_city\processed_json\117.json
# L:\Datasets\ocean_city\processed_json\118.json
# L:\Datasets\ocean_city\processed_json\119.json
# L:\Datasets\ocean_city\processed_json\120.json
# L:\Datasets\ocean_city\processed_json\121.json
# L:\Datasets\ocean_city\processed_json\122.json
# L:\Datasets\ocean_city\processed_json\123.json
# L:\Datasets\ocean_city\processed_json\124.json
# L:\Datasets\ocean_city\processed_json\125.json
# L:\Datasets\ocean_city\processed_json\126.json
# L:\Datasets\ocean_city\processed_json\127.json
# L:\Datasets\ocean_city\processed_json\128.json
# L:\Datasets\ocean_city\processed_json\129.json
# L:\Datasets\ocean_city\processed_json\13.json
# L:\Datasets\ocean_city\processed_json\130.json
# L:\Datasets\ocean_city\processed_json\131.json
# L:\Datasets\ocean_city\processed_json\132.json
# L:\Datasets\ocean_city\processed_json\133.json
# L:\Datasets\ocean_city\processed_json\134.json
# L:\Datasets\ocean_city\processed_json\135.json
# L:\Datasets\ocean_city\processed_json\136.json
# L:\Datasets\ocean_city\processed_json\137.json
# L:\Datasets\ocean_city\processed_json\139.json
# L:\Datasets\ocean_city\processed_json\14.json
# L:\Datasets\ocean_city\processed_json\140.json
# L:\Datasets\ocean_city\processed_json\141.json
# L:\Datasets\ocean_city\processed_json\142.json
# L:\Datasets\ocean_city\processed_json\143.json
# L:\Datasets\ocean_city\processed_json\144.json
# L:\Datasets\ocean_city\processed_json\145.json
# L:\Datasets\ocean_city\processed_json\146.json
# L:\Datasets\ocean_city\processed_json\147.json
# L:\Datasets\ocean_city\processed_json\148.json
# L:\Datasets\ocean_city\processed_json\149.json
# L:\Datasets\ocean_city\processed_json\15.json
# L:\Datasets\ocean_city\processed_json\150.json
# L:\Datasets\ocean_city\processed_json\151.json
# L:\Datasets\ocean_city\processed_json\152.json
# L:\Datasets\ocean_city\processed_json\153.json
# L:\Datasets\ocean_city\processed_json\156.json
# L:\Datasets\ocean_city\processed_json\157.json
# L:\Datasets\ocean_city\processed_json\158.json
# L:\Datasets\ocean_city\processed_json\159.json
# L:\Datasets\ocean_city\processed_json\16.json
# L:\Datasets\ocean_city\processed_json\160.json
# L:\Datasets\ocean_city\processed_json\161.json
# L:\Datasets\ocean_city\processed_json\162.json
# L:\Datasets\ocean_city\processed_json\163.json
# L:\Datasets\ocean_city\processed_json\164.json
# L:\Datasets\ocean_city\processed_json\165.json
# L:\Datasets\ocean_city\processed_json\166.json
# L:\Datasets\ocean_city\processed_json\17.json
# L:\Datasets\ocean_city\processed_json\175.json
# L:\Datasets\ocean_city\processed_json\176.json
# L:\Datasets\ocean_city\processed_json\177.json
# L:\Datasets\ocean_city\processed_json\178.json
# L:\Datasets\ocean_city\processed_json\180.json
# L:\Datasets\ocean_city\processed_json\183.json
# L:\Datasets\ocean_city\processed_json\185.json
# L:\Datasets\ocean_city\processed_json\186.json
# L:\Datasets\ocean_city\processed_json\187.json
# L:\Datasets\ocean_city\processed_json\188.json
# L:\Datasets\ocean_city\processed_json\189.json
# L:\Datasets\ocean_city\processed_json\190.json
# L:\Datasets\ocean_city\processed_json\191.json
# L:\Datasets\ocean_city\processed_json\192.json
# L:\Datasets\ocean_city\processed_json\193.json
# L:\Datasets\ocean_city\processed_json\2.json
# L:\Datasets\ocean_city\processed_json\20.json
# L:\Datasets\ocean_city\processed_json\21.json
# L:\Datasets\ocean_city\processed_json\22.json
# L:\Datasets\ocean_city\processed_json\23.json
# L:\Datasets\ocean_city\processed_json\24.json
# L:\Datasets\ocean_city\processed_json\26.json
# L:\Datasets\ocean_city\processed_json\27.json
# L:\Datasets\ocean_city\processed_json\28.json
# L:\Datasets\ocean_city\processed_json\29.json
# L:\Datasets\ocean_city\processed_json\3.json
# L:\Datasets\ocean_city\processed_json\30.json
# L:\Datasets\ocean_city\processed_json\32.json
# L:\Datasets\ocean_city\processed_json\34.json
# L:\Datasets\ocean_city\processed_json\35.json
# L:\Datasets\ocean_city\processed_json\36.json
# L:\Datasets\ocean_city\processed_json\37.json
# L:\Datasets\ocean_city\processed_json\38.json
# L:\Datasets\ocean_city\processed_json\39.json
# L:\Datasets\ocean_city\processed_json\4.json
# L:\Datasets\ocean_city\processed_json\40.json
# L:\Datasets\ocean_city\processed_json\41.json
# L:\Datasets\ocean_city\processed_json\42.json
# L:\Datasets\ocean_city\processed_json\43.json
# L:\Datasets\ocean_city\processed_json\44.json
# L:\Datasets\ocean_city\processed_json\45.json
# L:\Datasets\ocean_city\processed_json\46.json
# L:\Datasets\ocean_city\processed_json\47.json
# L:\Datasets\ocean_city\processed_json\48.json
# L:\Datasets\ocean_city\processed_json\5.json
# L:\Datasets\ocean_city\processed_json\50.json
# L:\Datasets\ocean_city\processed_json\51.json
# L:\Datasets\ocean_city\processed_json\52.json
# L:\Datasets\ocean_city\processed_json\53.json
# L:\Datasets\ocean_city\processed_json\55.json
# L:\Datasets\ocean_city\processed_json\56.json
# L:\Datasets\ocean_city\processed_json\57.json
# L:\Datasets\ocean_city\processed_json\59.json
# L:\Datasets\ocean_city\processed_json\6.json
# L:\Datasets\ocean_city\processed_json\60.json
# L:\Datasets\ocean_city\processed_json\61.json
# L:\Datasets\ocean_city\processed_json\62.json
# L:\Datasets\ocean_city\processed_json\63.json
# L:\Datasets\ocean_city\processed_json\67.json
# L:\Datasets\ocean_city\processed_json\68.json
# L:\Datasets\ocean_city\processed_json\69.json
# L:\Datasets\ocean_city\processed_json\70.json
# L:\Datasets\ocean_city\processed_json\71.json
# L:\Datasets\ocean_city\processed_json\72.json
# L:\Datasets\ocean_city\processed_json\73.json
# L:\Datasets\ocean_city\processed_json\74.json
# L:\Datasets\ocean_city\processed_json\75.json
# L:\Datasets\ocean_city\processed_json\76.json
# L:\Datasets\ocean_city\processed_json\77.json
# L:\Datasets\ocean_city\processed_json\78.json
# L:\Datasets\ocean_city\processed_json\79.json
# L:\Datasets\ocean_city\processed_json\8.json
# L:\Datasets\ocean_city\processed_json\80.json
# L:\Datasets\ocean_city\processed_json\81.json
# L:\Datasets\ocean_city\processed_json\82.json
# L:\Datasets\ocean_city\processed_json\83.json
# L:\Datasets\ocean_city\processed_json\84.json
# L:\Datasets\ocean_city\processed_json\85.json
# L:\Datasets\ocean_city\processed_json\86.json
# L:\Datasets\ocean_city\processed_json\87.json
# L:\Datasets\ocean_city\processed_json\88.json
# L:\Datasets\ocean_city\processed_json\89.json
# L:\Datasets\ocean_city\processed_json\9.json
# L:\Datasets\ocean_city\processed_json\90.json
# L:\Datasets\ocean_city\processed_json\91.json
# L:\Datasets\ocean_city\processed_json\92.json
# L:\Datasets\ocean_city\processed_json\93.json
# L:\Datasets\ocean_city\processed_json\94.json
# L:\Datasets\ocean_city\processed_json\95.json
# L:\Datasets\ocean_city\processed_json\96.json
# L:\Datasets\ocean_city\processed_json\97.json
# L:\Datasets\ocean_city\processed_json\98.json
# L:\Datasets\ocean_city\processed_json\99.json

# %% [markdown]
# ## modify json contents

# %%
for idx, file in enumerate(files):
      
    f = open(file, "r")
    
    jdata = json.load(f)
    f.close()
    
    old_name = jdata['imagePath']
    
    old_name, ext = os.path.splitext(old_name) 
    
    basename = os.path.basename(old_name)
    
    new_name = basename.split("_")[0] + ext
    
    print(new_name)
     
    jdata['imagePath'] =new_name
    
    f2 = open(file, "w")
    
    json.dump(jdata, f2, indent=2)
    
    f.close()
# Out:
# 1.jpg
# 10.jpg
# 100.jpg
# 101.jpg
# 102.jpg
# 103.jpg
# 104.jpg
# 105.jpg
# 106.jpg
# 107.jpg
# 108.jpg
# 109.jpg
# 11.jpg
# 110.jpg
# 111.jpg
# 112.jpg
# 113.jpg
# 114.jpg
# 115.jpg
# 116.jpg
# 117.jpg
# 118.jpg
# 119.jpg
# 120.jpg
# 121.jpg
# 122.jpg
# 123.jpg
# 124.jpg
# 125.jpg
# 126.jpg
# 127.jpg
# 128.jpg
# 129.jpg
# 13.jpg
# 130.jpg
# 131.jpg
# 132.jpg
# 133.jpg
# 134.jpg
# 135.jpg
# 136.jpg
# 137.jpg
# 139.jpg
# 14.jpg
# 140.jpg
# 141.jpg
# 142.jpg
# 143.jpg
# 144.jpg
# 145.jpg
# 146.jpg
# 147.jpg
# 148.jpg
# 149.jpg
# 15.jpg
# 150.jpg
# 151.jpg
# 152.jpg
# 153.jpg
# 156.jpg
# 157.jpg
# 158.jpg
# 159.jpg
# 16.jpg
# 160.jpg
# 161.jpg
# 162.jpg
# 163.jpg
# 164.jpg
# 165.jpg
# 166.jpg
# 17.jpg
# 175.jpg
# 176.jpg
# 177.jpg
# 178.jpg
# 180.jpg
# 183.jpg
# 185.jpg
# 186.jpg
# 187.jpg
# 188.jpg
# 189.jpg
# 190.jpg
# 191.jpg
# 192.jpg
# 193.jpg
# 2.jpg
# 20.jpg
# 21.jpg
# 22.jpg
# 23.jpg
# 24.jpg
# 26.jpg
# 27.jpg
# 28.jpg
# 29.jpg
# 3.jpg
# 30.jpg
# 32.jpg
# 34.jpg
# 35.jpg
# 36.jpg
# 37.jpg
# 38.jpg
# 39.jpg
# 4.jpg
# 40.jpg
# 41.jpg
# 42.jpg
# 43.jpg
# 44.jpg
# 45.jpg
# 46.jpg
# 47.jpg
# 48.jpg
# 5.jpg
# 50.jpg
# 51.jpg
# 52.jpg
# 53.jpg
# 55.jpg
# 56.jpg
# 57.jpg
# 59.jpg
# 6.jpg
# 60.jpg
# 61.jpg
# 62.jpg
# 63.jpg
# 67.jpg
# 68.jpg
# 69.jpg
# 70.jpg
# 71.jpg
# 72.jpg
# 73.jpg
# 74.jpg
# 75.jpg
# 76.jpg
# 77.jpg
# 78.jpg
# 79.jpg
# 8.jpg
# 80.jpg
# 81.jpg
# 82.jpg
# 83.jpg
# 84.jpg
# 85.jpg
# 86.jpg
# 87.jpg
# 88.jpg
# 89.jpg
# 9.jpg
# 90.jpg
# 91.jpg
# 92.jpg
# 93.jpg
# 94.jpg
# 95.jpg
# 96.jpg
# 97.jpg
# 98.jpg
# 99.jpg

# %%
def create_gqa_image_data(gqa_image_data, scene_graphs, forb_list):

    for img in scene_graphs.keys():
        if img not in forb_list:
            gqa_image_data.append({'width': scene_graphs[img]['width'],
                                   'url' : None,
                                   'height': scene_graphs[img]['height'],
                                   'image_id': int(img),
                                   'coco_id' : None,
                                   'flickr_id' : None,
                                   'anti_prop' : 0.0})
    return gqa_image_data

# %%
gqa_image_data = []

for name in ('val_sceneGraphs', 'train_sceneGraphs'):
    with open('//local-scratch/data/GQA/SceneGraphs/' + name + '.json') as json_file:
        obj_data = json.load(json_file)    
    
    gqa_image_data = create_gqa_image_data(gqa_image_data, obj_data, [])

with open('gqa_image_metadata.json', 'w') as outfile:  
    json.dump(gqa_image_data, outfile)

# %%
def create_obj_dict(img_list, obj_data, forb_list):
    
    for img in obj_data.keys():
        if img not in forb_list:
            tmp_dict = {'image_id' : int(img), 'objects' : [], 'image_url' : ''}
            tmp_list = []
            for obj in obj_data[img]['objects']:
                tmp_list.append({'synsets': [obj_data[img]['objects'][obj]['name']],
                                 'h': obj_data[img]['objects'][obj]['h'],
                                 'object_id': int(obj),
                                 'merged_object_ids': [],
                                 'names': [obj_data[img]['objects'][obj]['name']],
                                 'w': obj_data[img]['objects'][obj]['w'],
                                 'y': obj_data[img]['objects'][obj]['y'],
                                 'x': obj_data[img]['objects'][obj]['x']})

            tmp_dict['objects'] = tmp_list
            img_list.append(tmp_dict)
        
    return img_list

# %%
def create_rel_dict(cntr, rel_list, obj_data, forb_list):

    for img in obj_data.keys():
        if img not in forb_list:
            tmp_list = []
            for obj in obj_data[img]['objects']:
                for rel in obj_data[img]['objects'][obj]['relations']:
                    cntr += 1
                    subj = rel['object']
                    tmp_list.append({'predicate': rel['name'],
                                     'object': {'h': obj_data[img]['objects'][obj]['h'],
                                     'object_id': int(obj),
                                     'merged_object_ids': [],
                                     'synsets': [obj_data[img]['objects'][obj]['name']],
                                     'w': obj_data[img]['objects'][obj]['w'],
                                     'y': obj_data[img]['objects'][obj]['y'],
                                     'x': obj_data[img]['objects'][obj]['x'],
                                     'names': [obj_data[img]['objects'][obj]['name']]},
                                    'relationship_id': cntr,
                                    'synsets': [rel['name']],
                                    'subject': {'name': obj_data[img]['objects'][subj]['name'],
                                     'h': obj_data[img]['objects'][subj]['h'],
                                     'synsets': [obj_data[img]['objects'][subj]['name']],
                                     'object_id': int(subj),
                                     'w': obj_data[img]['objects'][subj]['w'],
                                     'y': obj_data[img]['objects'][subj]['y'],
                                     'x': obj_data[img]['objects'][subj]['x']}})
            rel_list.append({'relationships' : tmp_list, 'image_id' : int(img)})
    
    return cntr, rel_list

# %%
def create_attr_dict(attr_list, obj_data, forb_list):
    
    for img in obj_data.keys():
        if img not in forb_list:
            tmp_dict = {'image_id' : int(img), 'attributes' : []}
            tmp_list = []
            for obj in obj_data[img]['objects']:
                if obj_data[img]['objects'][obj]['attributes'] != []:
                    tmp_list.append({'synsets': [obj_data[img]['objects'][obj]['name']],
                                     'h': obj_data[img]['objects'][obj]['h'],
                                     'object_id': int(obj),
                                     'attributes' : obj_data[img]['objects'][obj]['attributes'],
                                     'names': [obj_data[img]['objects'][obj]['name']],
                                     'w': obj_data[img]['objects'][obj]['w'],
                                     'y': obj_data[img]['objects'][obj]['y'],
                                     'x': obj_data[img]['objects'][obj]['x']})
                else:
                    tmp_list.append({'synsets': [obj_data[img]['objects'][obj]['name']],
                                     'h': obj_data[img]['objects'][obj]['h'],
                                     'object_id': int(obj),
                                     'names': [obj_data[img]['objects'][obj]['name']],
                                     'w': obj_data[img]['objects'][obj]['w'],
                                     'y': obj_data[img]['objects'][obj]['y'],
                                     'x': obj_data[img]['objects'][obj]['x']})

            tmp_dict['attributes'] = tmp_list
            attr_list.append(tmp_dict)
        
    return attr_list

# %%
def save_to_file(text, name):

    with open(name, mode='wt', encoding='utf-8') as myfile:
        myfile.write('\n'.join(text))
        myfile.write('\n')

# %%
cntr = 0
img_list = []
rel_list = []
attr_list = []
gqa_image_data = []
forb_list = open("non_ex_haha.txt", "r").read().split('\n')

for name in ('val_sceneGraphs', 'train_sceneGraphs'):
    with open('//local-scratch/data/GQA/SceneGraphs/' + name + '.json') as json_file:
        obj_data = json.load(json_file)
        
    img_list = create_obj_dict(img_list, obj_data, forb_list)
    cntr, rel_list = create_rel_dict(cntr, rel_list, obj_data, forb_list)
    gqa_image_data = create_gqa_image_data(gqa_image_data, obj_data, forb_list)
    attr_list = create_attr_dict(attr_list, obj_data, forb_list)

# %%
relsMap = json.load(open('/home/lkochiev/Documents/SFU/NSM/vgLists/relInfo.json'))
save_to_file(list(relsMap.keys()), 'gqa_relationship_list.txt')

# %%
attrInfo = json.load(open('/home/lkochiev/Documents/SFU/NSM/vgLists/attrMap.json'))
merged = list(itertools.chain(*list(attrInfo.values())))
save_to_file(merged, 'gqa_attribute_list.txt')

# %%
catMap = json.load(open('/home/lkochiev/Documents/SFU/NSM/vgLists/hObjInfo.json'))
save_to_file(list(catMap.keys()), 'gqa_object_list.txt')

# %%
with open('gqa_objects.json', 'w') as outfile:
    json.dump(img_list, outfile)
    
with open('gqa_relationships.json', 'w') as outfile:
    json.dump(rel_list, outfile)
    
with open('gqa_image_metadata.json', 'w') as outfile:  
    json.dump(gqa_image_data, outfile)
    
with open('gqa_attributes.json', 'w') as outfile:
    json.dump(attr_list, outfile)

# %%
obj_ent = []
att_ent = []
rel_ent = []

for name in ('val_sceneGraphs', 'train_sceneGraphs'):
    with open('//local-scratch/data/GQA/SceneGraphs/' + name + '.json') as json_file:
        obj_data = json.load(json_file)
    
    for key in tqdm(obj_data.keys()):
        for obj in obj_data[key]['objects']:
            
            if obj_data[key]['objects'][obj]['name'] in obj_ent:
                continue
            else: 
                obj_ent.append(obj_data[key]['objects'][obj]['name'])
            
            for rel in obj_data[key]['objects'][obj]['relations']:
                if rel['name'] == 'licking':
                    print('licking')
                if rel['name'] in rel_ent:
                    continue
                else: 
                    rel_ent.append(rel['name'])
                    
            for att in obj_data[key]['objects'][obj]['attributes']:
                if att in att_ent:
                    continue
                else: 
                    att_ent.append(att)
# Out:
# 100%|██████████| 10696/10696 [00:00<00:00, 24711.95it/s]
# 100%|██████████| 74942/74942 [00:03<00:00, 24782.53it/s]

# %%
len(rel_ent), len(att_ent)
# Out:
# (65, 182)
